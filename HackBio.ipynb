# %% [markdown]
# <a href="https://colab.research.google.com/github/Jenny-codess/hackbio-bash/blob/main/HackBio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
mkdir hackbio

# %%
cd hackbio/
# Out:
# /content/hackbio

# %%
mkdir -p bash_course

# %%
ls
# Out:
# bash_course/

# %%
pwd
# Out:
# '/content/hackbio'

# %%
cd bash_course
# Out:
# /content/hackbio/bash_course

# %%
# %%bash
# touch intro.txt

# %%
ls -lh
# Out:
# total 0
# -rw-r--r-- 1 root root 0 Nov  9 22:39 intro.txt

# %%
# %%bash
# #to rename the intro txt file
# mv intro.txt bash_notes.txt

# %%
#to display the contents of the file
cat bash_notes.txt

# %%
# %%bash
# wget https://raw.githubusercontent.com/HackBio-Internship/public_datasets/refs/heads/main/metadata_sample.tsv
# Out:
# --2025-11-09 22:45:03--  https://raw.githubusercontent.com/HackBio-Internship/public_datasets/refs/heads/main/metadata_sample.tsv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 86 [text/plain]
# Saving to: ‘metadata_sample.tsv’
#
#      0K                                                       100% 5.04M=0s
#
# 2025-11-09 22:45:03 (5.04 MB/s) - ‘metadata_sample.tsv’ saved [86/86]

# %%
#search for the word 'niger' eliminating case sensitivity
# %%bash
grep -i 'niger' metadata_sample.tsv
# Out:
# ERS1887136	61	Nigeria

# %%
#save matchind detail to a mew file
# %%bash
grep -i 'niger' metadata_sample.tsv > rna_matches.txt

# %%
# %%bash
# touch students.txt

# %%
# %%bash
# cat students.txt
# Out:
# Jenny,12
# Matthew,22
# Valerie,24
# Sohmie,10
# Abigail,19
# Joy,18
# Testla,35

# %%
#to replace one student's name with another
# %%bash
sed 's/Valerie/Venus/' students.txt
# Out:
# Jenny,12
# Matthew,22
# Venus,24
# Sohmie,10
# Abigail,19
# Joy,18
# Testla,35

# %%
#Sort the file by the score column in ascending numeric order.
# %%bash
sort -t"," -n -k2,2 students.txt
# Out:
# Sohmie,10
# Jenny,12
# Joy,18
# Abigail,19
# Matthew,22
# Valerie,24
# Testla,35

# %%
# %%bash
# wget https://raw.githubusercontent.com/HackBio-Internship/public_datasets/refs/heads/main/R/Child_Variants.csv
# Out:
# --2025-11-09 23:00:10--  https://raw.githubusercontent.com/HackBio-Internship/public_datasets/refs/heads/main/R/Child_Variants.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1594229 (1.5M) [text/plain]
# Saving to: ‘Child_Variants.csv’
#
#      0K .......... .......... .......... .......... ..........  3% 4.10M 0s
#     50K .......... .......... .......... .......... ..........  6% 8.25M 0s
#    100K .......... .......... .......... .......... ..........  9% 6.27M 0s
#    150K .......... .......... .......... .......... .......... 12% 32.3M 0s
#    200K .......... .......... .......... .......... .......... 16% 28.8M 0s
#    250K .......... .......... .......... .......... .......... 19% 8.63M 0s
# ...

# %%
# %%bash
# mv Child_Variants.csv variants_local.csv

# %%
# %%bash
# ps -f
# Out:
# UID          PID    PPID  C STIME TTY          TIME CMD
# root           1       0  0 22:29 ?        00:00:00 /sbin/docker-init -- /datalab/run.sh
# root           6       1  0 22:29 ?        00:00:06 /tools/node/bin/node /datalab/web/app.js
# root           8       6  0 22:29 ?        00:00:01 /bin/bash -e /usr/local/colab/bin/oom_monitor.sh
# root          10       1  0 22:29 ?        00:00:00 /bin/bash -e /datalab/run.sh
# root          11      10  0 22:29 ?        00:00:01 /usr/colab/bin/kernel_manager_proxy --listen_port=6000 --target_port=9000 --logtostderr --listen_host=172.28.0.12 --target_host=172.28.0.12 --tunnel_background_save_url=https://colab.research.google.com/tun/m/cc48301118ce562b961b3c22d803539adc1e0c19/m-s-ugu6sjpxv2nm --tunnel_background_save_delay=10s --tunnel_periodic_background_save_frequency=30m0s --enable_output_coalescing=true --output_coalescing_required=true
# ...

# %%
# %%bash
# head  variants_local.csv
# Out:
# CHR,POS,dbSNP,REF,ALT,QUAL,GENE,ENST,MutantReads,COVERAGE,MutantReadPercent
# 1,69270,.,A,G,16,OR4F5,ENST00000335137,3,4,75
# 1,69511,rs75062661,A,G,200,OR4F5,ENST00000335137,24,27,88
# 1,69761,.,A,T,200,OR4F5,ENST00000335137,8,8,100
# 1,69897,rs75758884,T,C,59,OR4F5,ENST00000335137,3,3,100
# 1,877831,rs6672356,T,C,200,SAMD11,ENST00000342066,10,11,90
# 1,881627,rs2272757,G,A,200,NOC2L,ENST00000327044,52,56,92
# 1,887801,rs3828047,A,G,200,NOC2L,ENST00000327044,47,48,97
# 1,888639,rs3748596,T,C,200,NOC2L,ENST00000327044,23,24,95
# 1,888659,rs3748597,T,C,200,NOC2L,ENST00000327044,17,21,80

# %%
# %%bash
# echo "Fried Yam"; echo "another"
# Out:
# Fried Yam
# another

# %%
# %%bash
# # Assign a value to a variable
# name="World";
# echo "Hello, $name!"
# Out:
# Hello, World!

# %%
# %%bash
# touch script_1.sh;
# Out:
# bash: line 2: cd: script_1.sh: Not a directory
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# /tmp/ipython-input-3409659604.py in <cell line: 0>()
# ----> 1 get_ipython().run_cell_magic('bash', '', 'touch script_1.sh; \ncd script_1.sh\n')
#
# /usr/local/lib/python3.12/dist-packages/google/colab/_shell.py in run_cell_magic(self, magic_name, line, cell)
#     274     if line and not cell:
#     275       cell = ' '
# --> 276     return super().run_cell_magic(magic_name, line, cell)
#     277
#     278
#
# /usr/local/lib/python3.12/dist-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2471             with self.builtin_trap:
#    2472                 args = (magic_arg_s, cell)
# -> 2473                 result = fn(*args, **kwargs)
#    2474             return result
#    2475
#
# ...

# %%
cat script_1.sh
# Out:
# name="World"
# echo "Hello, $name!"

# %%
# %%bash
# bash script_1.sh
# Out:
# Hello, World

# %%
# %%bash
# touch script_2.sh

# %%
# %%bash
# cat script_2.sh
# Out:
# num=9
# if [ $num -gt 10 ]; then
# echo "$num is greater than 10"
# else
# echo "$num is less than 10"
# fi

# %%
# %%bash
# touch script_3.sh

# %%
# %%bash
# bash script_3.sh
# Out:
# script_3.sh: line 1: syntax error near unexpected token `$'do\r''
# '
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# /tmp/ipython-input-2348286851.py in <cell line: 0>()
# ----> 1 get_ipython().run_cell_magic('bash', '', 'bash script_3.sh\n')
#
# /usr/local/lib/python3.12/dist-packages/google/colab/_shell.py in run_cell_magic(self, magic_name, line, cell)
#     274     if line and not cell:
#     275       cell = ' '
# --> 276     return super().run_cell_magic(magic_name, line, cell)
#     277
#     278
#
# /usr/local/lib/python3.12/dist-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2471             with self.builtin_trap:
#    2472                 args = (magic_arg_s, cell)
# -> 2473                 result = fn(*args, **kwargs)
#    2474             return result
#    2475
#
# ...

# %%
# %%bash
# touch script_5.sh;
# mv script_5.sh script_4.sh

# %%
# %%bash
# #!/bin/bash
# # For Loop
# for i in {1..5}; do
# echo "Iteraction $i"
# done
# Out:
# Iteraction 1
# Iteraction 2
# Iteraction 3
# Iteraction 4
# Iteraction 5

# %%
# %%bash
# #!/bin/bash
# # Break and continue
# for i in {1..10}; do
#   if [ $i -eq 3 ]; then     #this skips 3 and moves to 4
#     continue
#   fi
#   echo "Number $i"
#   if [ $i -eq 7 ]; then
#     break
#   fi
# done
# Out:
# Number 1
# Number 2
# Number 4
# Number 5
# Number 6
# Number 7

# %%
# %%bash
# #!/bin/bash
# ls;
# touch greet.sh
# Out:
# bash_notes.txt
# greet.sh
# metadata_sample.tsv
# rna_matches.txt
# script_1.sh
# script_2.sh
# script_3.sh
# script_4.sh
# students.txt
# variants_local.csv

# %%
# %%bash
# #!/bin/bash
# bash greet.sh
# Out:
# Hello Hackbio

# %%
# %%bash
# touch check_num.sh

# %%
# %%bash
# #!/bin/bash
# bash check_num.sh

# %%
# %%bash
# #!/bin/bash
# num=25
# if [ $num -gt 50 ]; then
# echo "$num is greater than 50"
# else
# echo "50 or less"
# fi
# Out:
# 50 or less

# %%
# %%bash
# touch loop_control.sh

# %%
# %%bash
# #!/bin/bash
#
# for i in {1..10}; do
#   if [ $i -eq 4 ]; then
#     continue
#   fi
#   echo "Number $i"
#   if [ $i -eq 8 ]; then
#     break
#   fi
# done
# Out:
# Number 1
# Number 2
# Number 3
# Number 5
# Number 6
# Number 7
# Number 8

# %%
# %%bash
# #!/bin/bash
# bash loop_control.sh
